# %%
from lark import Lark
import re

# %%
def apply_meta_rules(gramatika):
    gramatika = re.sub(r"([a-z_]+)-TVP",      r' "\1:" UNQUOTED_STRING -> \1',   gramatika)
    gramatika = re.sub(r"([a-z_]+)-BT",       r' "\1:" ( TRUE | FALSE ) -> \1',  gramatika)
    gramatika = re.sub(r"([a-z_]+)-Tag (.*)", r' "\1:" \2 -> \1',                gramatika)
    return gramatika

# %%
parser = Lark(apply_meta_rules(r"""
    start : not_important* term_frame+ typedef?
    typedef : "[Typedef]" /(.|\n)+/
    not_important : /.+/? _NL
    
    TRUE: "true"
    FALSE: "false"
       
    class_id : id
    rel_id : id
    instance_id : id
    # ?id : URL_AS_ID | PREFIXED_ID | UNPREFIXED_ID
    URL_AS_ID  : ("https:" | "http:")  /(?:[^\s,\}\]\\\\]|\\\\.)+/ 
    PREFIXED_ID :  /[^\s:=]+:\s*(?:[^\s,\}\]\\\\]|\\\\.)+/             
    UNPREFIXED_ID: /(?:[^\s:,=\}\]\\\\]|\\\\.)+/
 
 
        UNQUOTED_STRING: /.+/

// line termination
    eol :  qualifier_block? HIDDEN_COMMENT? _NL
    HIDDEN_COMMENT : "!" /[^\n]*/
    # ?qualifier_block : "{" qualifier_list? "}"
    qualifier_list :  qualifier ("," qualifier)*
    qualifier : rel_id  "="  QUOTED_STRING                 // requiers that ID dosn't allow '='
    
    
    xref_list : "[" (xref_no_comma ("," xref_no_comma)*)? "]"
    xref: id QUOTED_STRING?               // instead of 'id' it cold be /\S+/ ???, (does it have to escape ] ?)
    xref_no_comma: id QUOTED_STRING ?
    
        term_frame : "[Term]" _NL "id:" class_id eol (term_frame_clause eol )*
        
        # ?term_frame_clause : is_anonymous-BT
                           | name-TVP
                           | namespace-Tag OBO_NAMESPACE
                           | alt_id-Tag id
                           | def-Tag QUOTED_STRING xref_list
                           | comment-TVP
                           | subset-Tag id                                           // Subset-ID  (def in header) 
                           | synonym-Tag QUOTED_STRING SYNONYM_SCOPE NAME? xref_list   // synonym-ID (def in header)
                           | xref-Tag xref
                           | builtin-BT
                           | property_value-Tag RELATION_ID   /.+/        // TODO
                           | is_a-Tag class_id
                           
                           | intersection_of-Tag  /.+/        // TODO: RElATION_ID? class_id
                           
                           | union_of-Tag class_id
                           | equivalent_to-Tag class_id
                           | disjoint_from-Tag class_id
                           | relationship-Tag RELATION_ID class_id
                           | is_obsolete-BT
                           | replaced_by-Tag class_id
                           | consider-Tag id
                           | created_by-Tag /.+/       // Person-ID
                           | creation_date-Tag /.+/       // ISO-8601-DateTime
                           //| /[^:]+:.+/          -> anything

                           
                            
        OBO_NAMESPACE : "cellular_component" | "biological_process" | "molecular_function"
        
        SYNONYM_SCOPE : "EXACT" | "BROAD" | "NARROW" | "RELATED"
        
        RELATION_ID : /\S+/
        
        # %import common.ESCAPED_STRING -> QUOTED_STRING
        # %import common.CNAME -> NAME
        # %import common.NEWLINE -> _NL
        # %import common.WS_INLINE
        # %ignore WS_INLINE
        
        

    """), parser="lalr", lexer="contextual")

text = r"""
[Term]
id: GO:32
def: "hello" [wikipedia:nesto[lepo\]tako]
"""

with open("../data/go_1.obo", "r") as obo_file:
    #tree = parser.parse(text)
    tree = parser.parse(obo_file.read())
    pass
    
# def showTree(t, ind=""):
#     global tree
#     if not t:
#         return
    
#     print(ind, end='')
#     if type(t) == type(tree):
#         print(t.data)
#         for childe in t.children:
#             showTree(childe, ind+" "*2)
#     else:
#         print(repr(t))
        
# showTree(tree)
# Out:
# CPU times: user 208 ms, sys: 0 ns, total: 208 ms
# Wall time: 206 ms

# %%
from lark import Transformer

# %%
class OBOTransformer(Transformer):  
    
    TRUE = lambda self, _: True
    FALSE = lambda self, _: False
    
    eol = lambda self, _: None
    
    def id(self, item): return item[0].value  # str
    def class_id(self, item): return item  # str
    def rel_id(self, item): return item[0].value  # str
    def instance_id(self, item): return item[0].value  # str
    def relation_id(self, item): return item[0].value  # str

    def xref_no_comma(self, items): return items[0].value # TODO
    xref_list = list



    
    

for x in OBOTransformer().transform(tree).children:
    for y in x.children:
        print y
    print "="*30
# Out:
# [Token(PREFIXED_ID, 'GO:0000001')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'mitochondrion inheritance')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'biological_process')])
# None
# Tree(def, [Token(QUOTED_STRING, '"The distribution of mitochondria, including the mitochondrial genome, into daughter cells after mitosis or meiosis, mediated by interactions between mitochondria and the cytoskeleton."'), ['GOC:mcc', 'PMID:10873824', 'PMID:11389764']])
# None
# Tree(term_frame_clause, [Token(QUOTED_STRING, '"mitochondrial inheritance"'), Token(SYNONYM_SCOPE, 'EXACT'), []])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0048308')]])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0048311')]])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0000002')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'mitochondrial genome maintenance')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'biological_process')])
# None
# Tree(def, [Token(QUOTED_STRING, '"The maintenance of the structure and integrity of the mitochondrial genome; includes replication and segregation of the mitochondrial chromosome."'), ['GOC:ai', 'GOC:vw']])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0007005')]])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0000003')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'reproduction')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'biological_process')])
# None
# Tree(alt_id, [Token(PREFIXED_ID, 'GO:0019952')])
# None
# Tree(alt_id, [Token(PREFIXED_ID, 'GO:0050876')])
# None
# Tree(def, [Token(QUOTED_STRING, '"The production of new individuals that contain some portion of genetic material inherited from one or more parent organisms."'), ['GOC:go_curators', 'GOC:isa_complete', 'GOC:jl', 'ISBN:0198506732']])
# None
# goslim_chembl
# None
# goslim_generic
# None
# goslim_pir
# None
# goslim_plant
# None
# gosubset_prok
# None
# Tree(term_frame_clause, [Token(QUOTED_STRING, '"reproductive physiological process"'), Token(SYNONYM_SCOPE, 'EXACT'), []])
# None
# Tree(xref, [Tree(xref, [Token(PREFIXED_ID, 'Wikipedia:Reproduction')])])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0008150')]])
# None
# Tree(disjoint_from, [[Token(PREFIXED_ID, 'GO:0044848')]])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0000005')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'obsolete ribosomal chaperone activity')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'molecular_function')])
# None
# Tree(def, [Token(QUOTED_STRING, '"OBSOLETE. Assists in the correct assembly of ribosomes or ribosomal subunits in vivo, but is not a component of the assembled ribosome when performing its normal biological function."'), ['GOC:jl', 'PMID:12150913']])
# None
# Tree(comment, [Token(UNQUOTED_STRING, 'This term was made obsolete because it refers to a class of gene products and a biological process rather than a molecular function.')])
# None
# Tree(term_frame_clause, [Token(QUOTED_STRING, '"ribosomal chaperone activity"'), Token(SYNONYM_SCOPE, 'EXACT'), []])
# None
# Tree(is_obsolete, [Token(TRUE, 'true')])
# None
# Tree(consider, [Token(PREFIXED_ID, 'GO:0042254')])
# None
# Tree(consider, [Token(PREFIXED_ID, 'GO:0044183')])
# None
# Tree(consider, [Token(PREFIXED_ID, 'GO:0051082')])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0000006')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'high-affinity zinc uptake transmembrane transporter activity')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'molecular_function')])
# None
# Tree(def, [Token(QUOTED_STRING, '"Enables the transfer of a solute or solutes from one side of a membrane to the other according to the reaction: Zn2+(out) = Zn2+(in), probably powered by proton motive force. In high-affinity transport the transporter is able to bind the solute even if it is only present at very low concentrations."'), ['TC:2.A.5.1.1']])
# None
# Tree(term_frame_clause, [Token(QUOTED_STRING, '"high affinity zinc uptake transmembrane transporter activity"'), Token(SYNONYM_SCOPE, 'EXACT'), []])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0005385')]])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0000007')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'low-affinity zinc ion transmembrane transporter activity')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'molecular_function')])
# None
# Tree(def, [Token(QUOTED_STRING, '"Catalysis of the transfer of a solute or solutes from one side of a membrane to the other according to the reaction: Zn2+ = Zn2+, probably powered by proton motive force. In low-affinity transport the transporter is able to bind the solute only if it is present at very high concentrations."'), ['GOC:mtg_transport', 'ISBN:0815340729']])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0005385')]])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0000008')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'obsolete thioredoxin')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'molecular_function')])
# None
# Tree(alt_id, [Token(PREFIXED_ID, 'GO:0000013')])
# None
# Tree(def, [Token(QUOTED_STRING, '"OBSOLETE. A small disulfide-containing redox protein that serves as a general protein disulfide oxidoreductase. Interacts with a broad range of proteins by a redox mechanism, based on the reversible oxidation of 2 cysteine thiol groups to a disulfide, accompanied by the transfer of 2 electrons and 2 protons. The net result is the covalent interconversion of a disulfide and a dithiol."'), ['GOC:kd']])
# None
# Tree(comment, [Token(UNQUOTED_STRING, 'This term was made obsolete because it represents gene products.')])
# None
# Tree(term_frame_clause, [Token(QUOTED_STRING, '"thioredoxin"'), Token(SYNONYM_SCOPE, 'EXACT'), []])
# None
# Tree(is_obsolete, [Token(TRUE, 'true')])
# None
# Tree(consider, [Token(PREFIXED_ID, 'GO:0003756')])
# None
# Tree(consider, [Token(PREFIXED_ID, 'GO:0015036')])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0000009')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'alpha-1,6-mannosyltransferase activity')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'molecular_function')])
# None
# Tree(def, [Token(QUOTED_STRING, '"Catalysis of the transfer of a mannose residue to an oligosaccharide, forming an alpha-(1->6) linkage."'), ['GOC:mcc', 'PMID:2644248']])
# None
# Tree(term_frame_clause, [Token(QUOTED_STRING, '"1,6-alpha-mannosyltransferase activity"'), Token(SYNONYM_SCOPE, 'EXACT'), []])
# None
# Tree(xref, [Tree(xref, [Token(PREFIXED_ID, 'EC:2.4.1')])])
# None
# Tree(xref, [Tree(xref, [Token(PREFIXED_ID, 'Reactome:REACT_22295'), Token(QUOTED_STRING, '"Addition of a third mannose to the N-glycan precursor by Alg2, Saccharomyces cerevisiae"')])])
# None
# Tree(xref, [Tree(xref, [Token(PREFIXED_ID, 'Reactome:REACT_22383'), Token(QUOTED_STRING, '"Addition of a third mannose to the N-glycan precursor by ALG2, Homo sapiens"')])])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0000030')]])
# None
# ==============================
# [Token(PREFIXED_ID, 'GO:0099616')]
# None
# Tree(name, [Token(UNQUOTED_STRING, 'extrinsic component of matrix side of mitochondrial inner membrane')])
# None
# Tree(namespace, [Token(OBO_NAMESPACE, 'cellular_component')])
# None
# Tree(def, [Token(QUOTED_STRING, '"The component of the matrix side of the mitochondrial inner membrane consisting of gene products and protein complexes that are loosely bound to one of its surfaces, but not integrated into the hydrophobic region.\\"\\n"'), ['GOC:dos']])
# None
# Tree(is_a, [[Token(PREFIXED_ID, 'GO:0031314')]])
# None
# GO:0019898 ! extrinsic component of membrane
# None
# part_of GO:0099617 ! matrix side of mitochondrial inner membrane
# None
# Tree(relationship, [Token(RELATION_ID, 'part_of'), [Token(PREFIXED_ID, 'GO:0099617')]])
# None
# ==============================
